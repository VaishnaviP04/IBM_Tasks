# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishnaviP04/test/blob/main/Vaishnavi_P_proj_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import matplotlib as mpl

# %%
pip install -U wbdata

# %%
 import wbdata 
 wbdata.get_source()
# Out:
#   id  name
# ----  --------------------------------------------------------------------
#    1  Doing Business
#    2  World Development Indicators
#    3  Worldwide Governance Indicators
#    5  Subnational Malnutrition Database
#    6  International Debt Statistics
#   11  Africa Development Indicators
#   12  Education Statistics
#   13  Enterprise Surveys
#   14  Gender Statistics
#   15  Global Economic Monitor
#   16  Health Nutrition and Population Statistics
#   18  IDA Results Measurement System
#   19  Millennium Development Goals
#   20  Quarterly Public Sector Debt
#   22  Quarterly External Debt Statistics SDDS
#   23  Quarterly External Debt Statistics GDDS
#   24  Poverty and Equity
#   25  Jobs
#   27  Global Economic Prospects
#   28  Global Financial Inclusion
#   29  The Atlas of Social Protection: Indicators of Resilience and Equity
#   30  Exporter Dynamics Database – Indicators at Country-Year Level
#   31  Country Policy and Institutional Assessment
# ...

# %%
wbdata.get_source(12)
# Out:
#   id  name
# ----  --------------------
#   12  Education Statistics

# %%
wbdata.get_country()
# Out:
# id    name
# ----  --------------------------------------------------------------------------------
# ABW   Aruba
# AFG   Afghanistan
# AFR   Africa
# AGO   Angola
# ALB   Albania
# AND   Andorra
# ARB   Arab World
# ARE   United Arab Emirates
# ARG   Argentina
# ARM   Armenia
# ASM   American Samoa
# ATG   Antigua and Barbuda
# AUS   Australia
# AUT   Austria
# AZE   Azerbaijan
# BDI   Burundi
# BEA   East Asia & Pacific (IBRD-only countries)
# BEC   Europe & Central Asia (IBRD-only countries)
# BEL   Belgium
# BEN   Benin
# BFA   Burkina Faso
# BGD   Bangladesh
# BGR   Bulgaria
# BHI   IBRD countries classified as high income
# BHR   Bahrain
# BHS   Bahamas, The
# BIH   Bosnia and Herzegovina
# BLA   Latin America & the Caribbean (IBRD-only countries)
# BLR   Belarus
# BLZ   Belize
# BMN   Middle East & North Africa (IBRD-only countries)
# BMU   Bermuda
# BOL   Bolivia
# BRA   Brazil
# BRB   Barbados
# BRN   Brunei Darussalam
# BSS   Sub-Saharan Africa (IBRD-only countries)
# ...

# %%
non_countries = ['World', 'IDA & IBRD total', 'Low & middle income', 'Middle income',
       'IBRD only', 'Early-demographic dividend', 'Lower middle income',
       'Upper middle income', 'Late-demographic dividend',
       'East Asia & Pacific', 'South Asia', 'South Asia (IDA & IBRD)',
       'East Asia & Pacific (excluding high income)',
       'East Asia & Pacific (IDA & IBRD countries)', 'OECD members', 'China',
       'IDA total', 'High income', 'Post-demographic dividend',
       'Europe & Central Asia', 'Latin America & Caribbean',
       'Latin America & the Caribbean (IDA & IBRD countries)',
       'Latin America & Caribbean (excluding high income)', 'IDA only',
       'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD countries)',
       'Sub-Saharan Africa (excluding high income)',
       'Least developed countries: UN classification',
       'Pre-demographic dividend', 'Middle East & North Africa',
       'European Union', 'Europe & Central Asia (IDA & IBRD countries)',
       'Low income', 'Heavily indebted poor countries (HIPC)',
       'Europe & Central Asia (excluding high income)',
       'Middle East & North Africa (excluding high income)', 'IDA blend',
       'Arab World', 'Middle East & North Africa (IDA & IBRD countries)',
       'North America', 'Fragile and conflict affected situations','Other small states','Euro area','Small states','Caribbean small states','Pacific island small states','Not classified']

# %%
len(non_countries)
# Out:
# 47

# %%
years = ['1960','1961','1962','1963','1964','1965','1965','1966','1967','1968','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986',
         '1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2020']

# %%
wbdata.get_indicator(source =12)
# Out:
# id                             name
# -----------------------------  --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# BAR.NOED.1519.FE.ZS            Barro-Lee: Percentage of female population age 15-19 with no education
# BAR.NOED.1519.ZS               Barro-Lee: Percentage of population age 15-19 with no education
# BAR.NOED.15UP.FE.ZS            Barro-Lee: Percentage of female population age 15+ with no education
# BAR.NOED.15UP.ZS               Barro-Lee: Percentage of population age 15+ with no education
# BAR.NOED.2024.FE.ZS            Barro-Lee: Percentage of female population age 20-24 with no education
# BAR.NOED.2024.ZS               Barro-Lee: Percentage of population age 20-24 with no education
# BAR.NOED.2529.FE.ZS            Barro-Lee: Percentage of female population age 25-29 with no education
# ...

# %%
#list of indicators required
indicators = {'SE.XPD.SECO.ZS':'Expenditure on secondary education (% of government expenditure on education)','SE.XPD.TOTL.GB.ZS':'Government expenditure on education, total (% of government expenditure)','SE.SEC.TCHR':'Secondary education, teachers','SE.SEC.PRIV.ZS':'School enrollment, secondary, private (% of total secondary)','SE.SEC.ENRL.TC.ZS':'Pupil-teacher ratio, secondary','IT.CMP.PCMP.P2':'Personal computers (per 100 people)','IT.NET.USER.P2':'Internet users (per 100 people)'}

# %%
expend_sec_students = {'SE.XPD.SECO.ZS':'Expenditure on secondary education (% of government expenditure on education)'}
expend_educa = {'SE.XPD.TOTL.GB.ZS':'Government expenditure on education, total (% of government expenditure)'}
enrol_sec_tchr = {'SE.SEC.TCHR':'Secondary education, teachers'}
enrol_sec_stud = {'SE.SEC.PRIV.ZS':'School enrollment, secondary, private (% of total secondary)'}
stud_tchr_ratio = {'SE.SEC.ENRL.TC.ZS':'Pupil - teacher ratio , secondary'}
pc_users = {'IT.CMP.PCMP.P2':'Personal computers (per 100 people)'}
net_users = {'IT.NET.SECR.P6':'Secure Internet users (per 1 million people)'}

# %%
wbdata.get_data
# Out:
# <function wbdata.api.get_data>

# %%
#obtaining dataframe for secure internet users
wbdata.get_data
df = wbdata.get_dataframe(net_users, country ='all',convert_date = False)

# %%
#performing basic operations 
df_net_users = df.unstack(level = 0).transpose()

# %%
df_net_users = df_net_users.drop(years,axis = 1)

# %%
df_net_users.reset_index(inplace = True)

# %%
df_net_users.set_index('country',inplace = True)

# %%
df_net_users.drop(non_countries, axis = 0,inplace = True )

# %%
#taking the years from 2010 - 2019 for consideration
df_net_users.sort_values(by=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019'],ascending = False,inplace = True)

# %%
df_net_users.head(10)
#final data frame of secure internet users
# Out:
# date                                                 level_0  ...           2019
# country                                                       ...
# Gibraltar       Secure Internet users (per 1 million people)  ...   16201.299665
# Liechtenstein   Secure Internet users (per 1 million people)  ...   48028.617270
# Bermuda         Secure Internet users (per 1 million people)  ...    7697.362245
# United States   Secure Internet users (per 1 million people)  ...  124014.176075
# Iceland         Secure Internet users (per 1 million people)  ...   70758.594349
# Netherlands     Secure Internet users (per 1 million people)  ...  130369.846851
# Faroe Islands   Secure Internet users (per 1 million people)  ...    4991.988167
# Cayman Islands  Secure Internet users (per 1 million people)  ...   16952.023157
# Malta           Secure Internet users (per 1 million people)  ...   10870.322071
# Denmark         Secure Internet users (per 1 million people)  ...  277133.679112
#
# ...

# %%
df_net_users = df_net_users.drop(['level_0'],axis = 1)

# %%
df_net_users.index
# Out:
# Index(['Gibraltar', 'Liechtenstein', 'Bermuda', 'United States', 'Iceland',
#        'Netherlands', 'Faroe Islands', 'Cayman Islands', 'Malta', 'Denmark',
#        ...
#        'Kiribati', 'Somalia', 'Sint Maarten (Dutch part)',
#        'Korea, Dem. People’s Rep.', 'Central African Republic',
#        'Guinea-Bissau', 'South Sudan', 'Tuvalu', 'Channel Islands', 'Kosovo'],
#       dtype='object', name='country', length=217)

# %%
#plotting for first four countries which has highest internet users

# %%
#for Gibraltar
x = np.array([i for i in range(2010,2020)])
y = df_net_users[df_net_users.index == 'Gibraltar'].values[0]
plt.title('Internet users in gibraltar ')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Liechtenstein
x = np.array([i for i in range(2010,2020)])
y = df_net_users[df_net_users.index == 'Liechtenstein'].values[0]
plt.title('Internet users in Liechtenstein ')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Bermuda
x = np.array([i for i in range(2010,2020)])
y = df_net_users[df_net_users.index == 'Bermuda'].values[0]
plt.title('Internet users in Bermuda')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Bermuda
x = np.array([i for i in range(2010,2020)])
y = df_net_users[df_net_users.index == 'India'].values[0]
plt.title('Internet users in Bermuda')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#students enrolled in private secondary

# %%
#getting the data frame 
wbdata.get_data
df = wbdata.get_dataframe(enrol_sec_stud, country ='all',convert_date = False)

# %%
df_enrol_sec_stud = df.unstack(level = 0).transpose()

# %%
df_enrol_sec_stud = df_enrol_sec_stud.drop(years,axis = 1)

# %%
df_enrol_sec_stud.reset_index(inplace = True)

# %%
df_enrol_sec_stud.set_index('country',inplace = True)

# %%
df_enrol_sec_stud.drop(non_countries, axis = 0,inplace = True )

# %%
#taking the years 210-2019 into consideration
df_enrol_sec_stud.sort_values(by=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019'],ascending = False,inplace = True)

# %%
df_enrol_sec_stud.head()
# Out:
# date                                                        level_0  ...       2019
# country                                                              ...
# Macao SAR, China  School enrollment, secondary, private (% of to...  ...  96.253166
# Bangladesh        School enrollment, secondary, private (% of to...  ...  87.601982
# Aruba             School enrollment, secondary, private (% of to...  ...        NaN
# Tonga             School enrollment, secondary, private (% of to...  ...        NaN
# Belize            School enrollment, secondary, private (% of to...  ...  66.314812
#
# [5 rows x 11 columns]

# %%
df_enrol_sec_stud = df_enrol_sec_stud.drop('level_0',axis = 1)

# %%
#final data frame for plotting
df_enrol_sec_stud
# Out:
# date                        2010       2011  ...       2018       2019
# country                                      ...
# Macao SAR, China       95.356079  95.347092  ...  95.986168  96.253166
# Bangladesh             95.114578  94.791496  ...        NaN  87.601982
# Aruba                  91.773361  91.569527  ...        NaN        NaN
# Tonga                  64.221428  65.248077  ...        NaN        NaN
# Belize                 63.206219  63.000542  ...        NaN  66.314812
# ...                          ...        ...  ...        ...        ...
# Turkmenistan                 NaN        NaN  ...        NaN        NaN
# Uganda                       NaN        NaN  ...        NaN        NaN
# Vietnam                      NaN        NaN  ...        NaN        NaN
# Virgin Islands (U.S.)        NaN        NaN  ...        NaN        NaN
# Zambia                       NaN        NaN  ...        NaN        NaN
#
# [217 rows x 10 columns]

# %%
df_enrol_sec_stud.index
# Out:
# Index(['Macao SAR, China', 'Bangladesh', 'Aruba', 'Tonga', 'Belize',
#        'Guatemala', 'Grenada', 'Lebanon', 'Chile', 'Belgium',
#        ...
#        'Palau', 'San Marino', 'Somalia', 'St. Martin (French part)',
#        'Trinidad and Tobago', 'Turkmenistan', 'Uganda', 'Vietnam',
#        'Virgin Islands (U.S.)', 'Zambia'],
#       dtype='object', name='country', length=217)

# %%
#let's plot for first three countries
#for Macao SAR, China
x = np.array([i for i in range(2010,2020)])
y = df_enrol_sec_stud[df_enrol_sec_stud.index == 'Macao SAR, China'].values[0]
plt.title('enrollment to secondary private')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Bangladesh
x = np.array([i for i in range(2010,2020)])
y = df_enrol_sec_stud[df_enrol_sec_stud.index == 'Bangladesh'].values[0]
plt.title('enrollment to secondary private')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Tonga
x = np.array([i for i in range(2010,2020)])
y = df_enrol_sec_stud[df_enrol_sec_stud.index == 'Tonga'].values[0]
plt.title('enrollment to secondary private')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#Expenditure on secondary education

# %%
#getting the data frame 
wbdata.get_data
df = wbdata.get_dataframe(expend_sec_students, country ='all',convert_date = False)

# %%
#perfoming basic operation 
df_expend_sec_stud = df.unstack(level = 0).transpose()

# %%
df_expend_sec_stud = df_expend_sec_stud.drop(years,axis = 1)

# %%
df_expend_sec_stud.reset_index(inplace = True)

# %%
df_expend_sec_stud.set_index('country',inplace = True)

# %%
df_expend_sec_stud.drop(non_countries, axis = 0,inplace = True )

# %%
#taking the years 210-2019 into consideration
df_expend_sec_stud.sort_values(by=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019'],ascending = False,inplace = True)

# %%
df_expend_sec_stud.head()
# Out:
# date                                                   level_0  ...  2019
# country                                                         ...
# Bhutan       Expenditure on secondary education (% of gover...  ...   NaN
# Mali         Expenditure on secondary education (% of gover...  ...   NaN
# Congo, Rep.  Expenditure on secondary education (% of gover...  ...   NaN
# Sri Lanka    Expenditure on secondary education (% of gover...  ...   NaN
# Cameroon     Expenditure on secondary education (% of gover...  ...   NaN
#
# [5 rows x 11 columns]

# %%
df_expend_sec_stud = df_expend_sec_stud.drop('level_0',axis =1)

# %%
df_expend_sec_stud.shape
# Out:
# (217, 10)

# %%
#final data frame for plotting
df_expend_sec_stud.head(20)
# Out:
# date                    2010      2011      2012  ...      2017      2018  2019
# country                                           ...
# Bhutan              53.87650  56.73914       NaN  ...       NaN       NaN   NaN
# Mali                53.77242  37.97895  39.91703  ...  37.00151       NaN   NaN
# Congo, Rep.         53.33168       NaN       NaN  ...       NaN       NaN   NaN
# Sri Lanka           53.22425  51.45251  50.77935  ...  51.17880  45.74178   NaN
# Cameroon            52.73901  48.86979  52.55314  ...       NaN       NaN   NaN
# Mauritius           52.64606  48.71658  53.75406  ...  63.08222  62.72406   NaN
# Iran, Islamic Rep.  49.18235  39.27918  41.42852  ...  33.03826  34.40004   NaN
# United Kingdom      48.31804  41.57060       NaN  ...       NaN       NaN   NaN
# Slovak Republic     46.93986  44.58291  44.13289  ...       NaN       NaN   NaN
# Brunei Darussalam   46.78163       NaN       NaN  ...       NaN       NaN   NaN
# ...

# %%
df_expend_sec_stud.index
# Out:
# Index(['Bhutan', 'Mali', 'Congo, Rep.', 'Sri Lanka', 'Cameroon', 'Mauritius',
#        'Iran, Islamic Rep.', 'United Kingdom', 'Slovak Republic',
#        'Brunei Darussalam',
#        ...
#        'Trinidad and Tobago', 'Turkey', 'Turkmenistan', 'Tuvalu',
#        'United Arab Emirates', 'Uzbekistan', 'Venezuela, RB',
#        'Virgin Islands (U.S.)', 'West Bank and Gaza', 'Yemen, Rep.'],
#       dtype='object', name='country', length=217)

# %%
#for Mali
x = np.array([i for i in range(2010,2020)])
y = df_expend_sec_stud[df_expend_sec_stud.index == 'Mali'].values[0]
plt.title('Expenditure on secondary education')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Sri Lanka
x = np.array([i for i in range(2010,2020)])
y = df_expend_sec_stud[df_expend_sec_stud.index == 'Sri Lanka'].values[0]
plt.title('Expenditure on secondary education')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Mauritius
x = np.array([i for i in range(2010,2020)])
y = df_expend_sec_stud[df_expend_sec_stud.index == 'Mauritius'].values[0]
plt.title('Expenditure on secondary education')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#Government expenditure on education

# %%
#getting the data frame 
wbdata.get_data
df = wbdata.get_dataframe(expend_educa, country ='all',convert_date = False)

# %%
#perfoming basic operation 
df_expend_educa = df.unstack(level = 0).transpose()

# %%
df_expend_educa = df_expend_educa.drop(years,axis = 1)

# %%
df_expend_educa.reset_index(inplace = True)

# %%
df_expend_educa.set_index('country',inplace = True)

# %%
df_expend_educa.drop(non_countries, axis = 0,inplace = True )

# %%
#taking the years 210-2019 into consideration
df_expend_educa.sort_values(by=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019'],ascending = False,inplace = True)

# %%
df_expend_educa = df_expend_educa.drop('level_0',axis =1)

# %%
#final data frame for plotting
df_expend_educa.head(20)
# Out:
# date                        2010       2011  ...       2018       2019
# country                                      ...
# Ethiopia               26.304041  29.674431  ...        NaN        NaN
# Benin                  26.143961        NaN  ...  17.709181        NaN
# Namibia                26.123510        NaN  ...        NaN        NaN
# Tunisia                24.846830        NaN  ...        NaN        NaN
# Congo, Rep.            24.727779        NaN  ...  15.567680        NaN
# Senegal                24.046350  21.086969  ...  21.529409        NaN
# Costa Rica             22.880890  23.009621  ...  26.086670        NaN
# Cote d'Ivoire          22.772751  22.426861  ...  18.331671        NaN
# Nicaragua              22.753670        NaN  ...        NaN        NaN
# Belize                 22.381800        NaN  ...  21.365290        NaN
# Moldova                22.267010  21.915880  ...  17.461100        NaN
# Aruba                  22.143660  21.745461  ...        NaN        NaN
# ...

# %%
df_expend_educa.index
# Out:
# Index(['Ethiopia', 'Benin', 'Namibia', 'Tunisia', 'Congo, Rep.', 'Senegal',
#        'Costa Rica', 'Cote d'Ivoire', 'Nicaragua', 'Belize',
#        ...
#        'Tonga', 'Trinidad and Tobago', 'Turkey', 'Tuvalu',
#        'United Arab Emirates', 'United States', 'Venezuela, RB',
#        'Virgin Islands (U.S.)', 'West Bank and Gaza', 'Yemen, Rep.'],
#       dtype='object', name='country', length=217)

# %%
#for Benin
x = np.array([i for i in range(2010,2020)])
y = df_expend_educa[df_expend_educa.index == 'Benin'].values[0]
plt.title('Government expenditure on education')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Senegal
x = np.array([i for i in range(2010,2020)])
y = df_expend_educa[df_expend_educa.index == 'Senegal'].values[0]
plt.title('Government expenditure on education')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
x = np.array([i for i in range(2010,2020)])
y = df_expend_educa[df_expend_educa.index == 'India'].values[0]
plt.title('Government expenditure on education')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#Secondary education, teachers

# %%
#getting the data frame 
wbdata.get_data
df = wbdata.get_dataframe(enrol_sec_tchr, country ='all',convert_date = False)

# %%
#perfoming basic operation 
df_enrol_sec_tchr = df.unstack(level = 0).transpose()

# %%
df_enrol_sec_tchr = df_enrol_sec_tchr.drop(years,axis = 1)

# %%
df_enrol_sec_tchr.reset_index(inplace = True)

# %%
df_enrol_sec_tchr.set_index('country',inplace = True)

# %%
df_enrol_sec_tchr.drop(non_countries, axis = 0,inplace = True )

# %%
#taking the years 210-2019 into consideration
df_enrol_sec_tchr.sort_values(by=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019'],ascending = False,inplace = True)

# %%
df_enrol_sec_tchr =df_enrol_sec_tchr.drop('level_0',axis =1)

# %%
#final data frame for plotting
df_enrol_sec_tchr.head(20)
# Out:
# date                                 2010  ...          2019
# country                                    ...
# India                           4251657.0  ...  6.103309e+06
# Indonesia                       1640533.0  ...           NaN
# Brazil                          1412582.0  ...           NaN
# Central Europe and the Baltics   803078.0  ...  6.993122e+05
# Mexico                           652140.0  ...           NaN
# Japan                            613851.0  ...           NaN
# Germany                          593815.0  ...           NaN
# France                           463172.0  ...           NaN
# Bangladesh                       400052.0  ...  4.067160e+05
# Nigeria                          390427.0  ...           NaN
# Uzbekistan                       342064.0  ...  3.751240e+05
# Spain                            294775.0  ...           NaN
# Poland                           273368.0  ...           NaN
# Korea, Rep.                      224503.0  ...           NaN
# ...

# %%
df_enrol_sec_tchr.index
# Out:
# Index(['India', 'Indonesia', 'Brazil', 'Central Europe and the Baltics',
#        'Mexico', 'Japan', 'Germany', 'France', 'Bangladesh', 'Nigeria',
#        ...
#        'Somalia', 'St. Martin (French part)', 'Sudan', 'Syrian Arab Republic',
#        'Trinidad and Tobago', 'Venezuela, RB', 'Vietnam',
#        'Virgin Islands (U.S.)', 'Yemen, Rep.', 'Zambia'],
#       dtype='object', name='country', length=217)

# %%
#for India
x = np.array([i for i in range(2010,2020)])
y = df_enrol_sec_tchr[df_enrol_sec_tchr.index == 'India'].values[0]
plt.title('Secondary education, teachers')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for Indonesia
x = np.array([i for i in range(2010,2020)])
y = df_enrol_sec_tchr[df_enrol_sec_tchr.index == 'Indonesia'].values[0]
plt.title('Secondary education, teachers')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#Pupil - teacher ratio , secondary

# %%
#getting the data frame 
wbdata.get_data
df = wbdata.get_dataframe(stud_tchr_ratio, country ='all',convert_date = False)

# %%
#perfoming basic operation
df_stud_tchr_ratio = df.unstack(level = 0).transpose()

# %%
df_stud_tchr_ratio = df_stud_tchr_ratio.drop(years,axis = 1)

# %%
df_stud_tchr_ratio.reset_index(inplace = True)

# %%
df_stud_tchr_ratio.set_index('country',inplace = True)

# %%
df_stud_tchr_ratio.drop(non_countries, axis = 0,inplace = True )

# %%
#taking the years 210-2019 into consideration
df_stud_tchr_ratio.sort_values(by=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019'],ascending = False,inplace = True)

# %%
df_stud_tchr_ratio = df_stud_tchr_ratio.drop('level_0',axis =1)

# %%
df_stud_tchr_ratio.head(20)
# Out:
# date                    2010      2011      2012  ...      2017      2018     2019
# country                                           ...
# Malawi              43.23009  42.12850  41.52301  ...       NaN  72.31002      NaN
# Ethiopia            43.07495  40.33126  40.35064  ...       NaN       NaN      NaN
# Eritrea             38.68424  39.49376  37.88873  ...  36.56873  35.02165      NaN
# Mozambique          34.12402  33.23384  33.07411  ...  36.54379       NaN      NaN
# Myanmar             34.07819       NaN       NaN  ...  26.41848  27.24679      NaN
# Chad                32.47438  31.98235  29.77340  ...       NaN       NaN      NaN
# Nepal               31.97247  29.70178  29.56574  ...  28.82411       NaN  28.2567
# Niger               30.83710  34.67953       NaN  ...  29.73171       NaN      NaN
# Nicaragua           30.83047       NaN       NaN  ...       NaN       NaN      NaN
# Burkina Faso        30.25804  26.48814  26.33301  ...  23.33086  23.11995      NaN
# ...

# %%
#for Malawi
x = np.array([i for i in range(2010,2020)])
y = df_stud_tchr_ratio[df_stud_tchr_ratio.index == 'Malawi'].values[0]
plt.title('Pupil - teacher ratio , secondary')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
#for India
x = np.array([i for i in range(2010,2020)])
y = df_stud_tchr_ratio[df_stud_tchr_ratio.index == 'India'].values[0]
plt.title('Pupil - teacher ratio , secondary')
plt.ylabel('count')
plt.xlabel('Years ')
plt.plot(x,y)

# %%
### listing the countries from all the require data frames
import pandas as pd
df = pd.DataFrame()

# %%
df1 =pd.DataFrame(df_net_users.index)
df1
df1.rename(columns = {'country':'df_net_users'},inplace = True)
df1.head()
# Out:
#     df_net_users
# 0      Gibraltar
# 1  Liechtenstein
# 2        Bermuda
# 3  United States
# 4        Iceland

# %%
df2= pd.DataFrame(df_enrol_sec_stud.index)
df2
df2.rename(columns = {'country':'df_enrol_sec_stud'},inplace = True)
df2.head()
# Out:
#   df_enrol_sec_stud
# 0  Macao SAR, China
# 1        Bangladesh
# 2             Aruba
# 3             Tonga
# 4            Belize

# %%
df3 = pd.DataFrame(df_expend_sec_stud.index)
df3
df3.rename(columns = {'country':'df_expend_sec_stud'},inplace = True)
df3.head()
# Out:
#   df_expend_sec_stud
# 0             Bhutan
# 1               Mali
# 2        Congo, Rep.
# 3          Sri Lanka
# 4           Cameroon

# %%
df4 = pd.DataFrame(df_expend_educa.index)
df4
df4.rename(columns = {'country':'df_expend_educa'},inplace = True)
df4.head()
# Out:
#   df_expend_educa
# 0        Ethiopia
# 1           Benin
# 2         Namibia
# 3         Tunisia
# 4     Congo, Rep.

# %%
df5 = pd.DataFrame(df_enrol_sec_tchr.index)
df5
df5.rename(columns = {'country':'df_enrol_sec_tchr'},inplace = True)
df5.head()
# Out:
#                 df_enrol_sec_tchr
# 0                           India
# 1                       Indonesia
# 2                          Brazil
# 3  Central Europe and the Baltics
# 4                          Mexico

# %%
df6 = pd.DataFrame(df_stud_tchr_ratio.index)
df6
df6.rename(columns = {'country':'df_stud_tchr_ratio'},inplace = True)
df6.head()
# Out:
#   df_stud_tchr_ratio
# 0             Malawi
# 1           Ethiopia
# 2            Eritrea
# 3         Mozambique
# 4            Myanmar

# %%
frames = [df1,df2,df3,df4,df5,df6]

# %%
dfall = pd.concat(frames,axis = 1)

# %%
dfall
# Out:
#         df_net_users  ...     df_stud_tchr_ratio
# 0          Gibraltar  ...                 Malawi
# 1      Liechtenstein  ...               Ethiopia
# 2            Bermuda  ...                Eritrea
# 3      United States  ...             Mozambique
# 4            Iceland  ...                Myanmar
# ..               ...  ...                    ...
# 212    Guinea-Bissau  ...          Venezuela, RB
# 213      South Sudan  ...                Vietnam
# 214           Tuvalu  ...  Virgin Islands (U.S.)
# 215  Channel Islands  ...            Yemen, Rep.
# 216           Kosovo  ...                 Zambia
#
# [217 rows x 6 columns]

# %%
dfall.head(40)
# Out:
#               df_net_users  ...              df_stud_tchr_ratio
# 0                Gibraltar  ...                          Malawi
# 1            Liechtenstein  ...                        Ethiopia
# 2                  Bermuda  ...                         Eritrea
# 3            United States  ...                      Mozambique
# 4                  Iceland  ...                         Myanmar
# 5              Netherlands  ...                            Chad
# 6            Faroe Islands  ...                           Nepal
# 7           Cayman Islands  ...                           Niger
# 8                    Malta  ...                       Nicaragua
# 9                  Denmark  ...                    Burkina Faso
# 10                  Norway  ...                         Burundi
# 11             Switzerland  ...                      Bangladesh
# 12               Australia  ...              Dominican Republic
# 13             New Zealand  ...                 Solomon Islands
# ...

# %% [markdown]
# ### FROM THE ABOVE DATA FRAME WE CAN SEE THAT INDIA,BANGALDESH, INDONESIA ,Hong Kong SAR, China ARE MORE OCCURING

# %% [markdown]
# ### let us plot graph for  all the indicators for each country

# %% [markdown]
# ### FOR INDIA

# %%
 fig = plt.figure(figsize =(25,25)) 
ax1 = fig.add_subplot(3, 3, 1) 
ax2 = fig.add_subplot(3, 3, 2) 
ax3 = fig.add_subplot(3, 3, 3)
ax4 = fig.add_subplot(3, 3, 4)
ax5 = fig.add_subplot(3, 3, 5)
ax6 = fig.add_subplot(3,3, 6)

xdata1 = np.array([i for i in range(2010,2020)])

ydata1 = df_net_users[df_net_users.index == 'India'].values[0]
ydata2 = df_enrol_sec_stud[df_enrol_sec_stud.index == 'India'].values[0]
ydata3 = df_expend_sec_stud[df_expend_sec_stud.index == 'India'].values[0]
ydata4 = df_expend_educa[df_expend_educa.index == 'India'].values[0]
ydata5 = df_enrol_sec_tchr[df_enrol_sec_tchr.index == 'India'].values[0]
ydata6 = df_stud_tchr_ratio[df_stud_tchr_ratio.index == 'India'].values[0]

ax1.plot(xdata1, ydata1, color ='tab:blue') 
ax1.title.set_text("net users")
ax2.plot(xdata1, ydata2, color ='tab:orange') 
ax2.title.set_text("students enrollment to secondary")
ax3.plot(xdata1, ydata3, color ='tab:red') 
ax3.title.set_text("expenditure on secondary")
ax4.plot(xdata1,ydata4, color = 'tab:green')
ax4.title.set_text("expenditure on education")
ax5.plot(xdata1,ydata5, color = 'tab:purple')
ax5.title.set_text("teachers enrollment to secondary")
ax6.plot(xdata1,ydata6, color = 'tab:blue')
ax6.title.set_text("student teacher ratio")

plt.suptitle("India Graphs",fontsize = 15)
plt.show()

# %% [markdown]
# ## FROM THE ABOVE GRAPHS WE CAN SAY THAT FOR INDIA OUR SERVICE CAN BE PROVIDED AS STUDENTS ARE MORE, EXPENDITURE IS ALSO MORE

# %% [markdown]
# ### FOR BANGALDESH

# %%
 fig = plt.figure(figsize =(25,25)) 
ax1 = fig.add_subplot(3, 3, 1) 
ax2 = fig.add_subplot(3, 3, 2) 
ax3 = fig.add_subplot(3, 3, 3)
ax4 = fig.add_subplot(3, 3, 4)
ax5 = fig.add_subplot(3, 3, 5)
ax6 = fig.add_subplot(3,3, 6)

xdata1 = np.array([i for i in range(2010,2020)])

ydata1 = df_net_users[df_net_users.index == 'Bangladesh'].values[0]
ydata2 = df_enrol_sec_stud[df_enrol_sec_stud.index == 'Bangladesh'].values[0]
ydata3 = df_expend_sec_stud[df_expend_sec_stud.index == 'Bangladesh'].values[0]
ydata4 = df_expend_educa[df_expend_educa.index == 'Bangladesh'].values[0]
ydata5 = df_enrol_sec_tchr[df_enrol_sec_tchr.index == 'Bangladesh'].values[0]
ydata6 = df_stud_tchr_ratio[df_stud_tchr_ratio.index == 'Bangladesh'].values[0]

ax1.plot(xdata1, ydata1, color ='tab:blue') 
ax1.title.set_text("net users")
ax2.plot(xdata1, ydata2, color ='tab:orange') 
ax2.title.set_text("students enrollment to secondary")
ax3.plot(xdata1, ydata3, color ='tab:red') 
ax3.title.set_text("expenditure on secondary")
ax4.plot(xdata1,ydata4, color = 'tab:green')
ax4.title.set_text("expenditure on education")
ax5.plot(xdata1,ydata5, color = 'tab:purple')
ax5.title.set_text("teachers enrollment to secondary")
ax6.plot(xdata1,ydata6, color = 'tab:blue')
ax6.title.set_text("student teacher ratio")

plt.suptitle("Bangladesh Graphs",fontsize = 15)
plt.show()

# %% [markdown]
# ### FROM ABOVE GRAPHS WE CAN CONCLUDE THAT BANGLADESH DOESN'T HAVE STUDENTS ENROLLMENT AND ISN'T SUITABLE FOR OUR SERVICE THOUGH SECURE INTERNET IS QUITE GOOD

# %% [markdown]
# ### FOR INDONESIA

# %%
fig = plt.figure(figsize =(25,25)) 
ax1 = fig.add_subplot(3, 3, 1) 
ax2 = fig.add_subplot(3, 3, 2) 
ax3 = fig.add_subplot(3, 3, 3)
ax4 = fig.add_subplot(3, 3, 4)
ax5 = fig.add_subplot(3, 3, 5)
ax6 = fig.add_subplot(3,3, 6)

xdata1 = np.array([i for i in range(2010,2020)])

ydata1 = df_net_users[df_net_users.index == 'Indonesia'].values[0]
ydata2 = df_enrol_sec_stud[df_enrol_sec_stud.index == 'Indonesia'].values[0]
ydata3 = df_expend_sec_stud[df_expend_sec_stud.index == 'Indonesia'].values[0]
ydata4 = df_expend_educa[df_expend_educa.index == 'Indonesia'].values[0]
ydata5 = df_enrol_sec_tchr[df_enrol_sec_tchr.index == 'Indonesia'].values[0]
ydata6 = df_stud_tchr_ratio[df_stud_tchr_ratio.index == 'Indonesia'].values[0]

ax1.plot(xdata1, ydata1, color ='tab:blue') 
ax1.title.set_text("net users")
ax2.plot(xdata1, ydata2, color ='tab:orange') 
ax2.title.set_text("students enrollment to secondary")
ax3.plot(xdata1, ydata3, color ='tab:red') 
ax3.title.set_text("expenditure on secondary")
ax4.plot(xdata1,ydata4, color = 'tab:green')
ax4.title.set_text("expenditure on education")
ax5.plot(xdata1,ydata5, color = 'tab:purple')
ax5.title.set_text("teachers enrollment to secondary")
ax6.plot(xdata1,ydata6, color = 'tab:blue')
ax6.title.set_text("student teacher ratio")

plt.suptitle("Indonesia Graphs",fontsize = 15)
plt.show()

# %% [markdown]
# ### THOUGH GOVT EXPENDITURE IS MORE , THE STUDENTS ENROLLMENT ARE COMPARETIVELY LESS , SO INDONESIA IS LESS SUITABLE THAN OTHERS

# %% [markdown]
# ### FOR Hong Kong SAR, China

# %%
fig = plt.figure(figsize =(25,25)) 
ax1 = fig.add_subplot(3, 3, 1) 
ax2 = fig.add_subplot(3, 3, 2) 
ax3 = fig.add_subplot(3, 3, 3)
ax4 = fig.add_subplot(3, 3, 4)
ax5 = fig.add_subplot(3, 3, 5)
ax6 = fig.add_subplot(3,3, 6)

xdata1 = np.array([i for i in range(2010,2020)])

ydata1 = df_net_users[df_net_users.index == 'Hong Kong SAR, China'].values[0]
ydata2 = df_enrol_sec_stud[df_enrol_sec_stud.index == 'Hong Kong SAR, China'].values[0]
ydata3 = df_expend_sec_stud[df_expend_sec_stud.index == 'Hong Kong SAR, China'].values[0]
ydata4 = df_expend_educa[df_expend_educa.index == 'Hong Kong SAR, China'].values[0]
ydata5 = df_enrol_sec_tchr[df_enrol_sec_tchr.index == 'Hong Kong SAR, China'].values[0]
ydata6 = df_stud_tchr_ratio[df_stud_tchr_ratio.index == 'Hong Kong SAR, China'].values[0]

ax1.plot(xdata1, ydata1, color ='tab:blue') 
ax1.title.set_text("net users")
ax2.plot(xdata1, ydata2, color ='tab:orange') 
ax2.title.set_text("students enrollment to secondary")
ax3.plot(xdata1, ydata3, color ='tab:red') 
ax3.title.set_text("expenditure on secondary")
ax4.plot(xdata1,ydata4, color = 'tab:green')
ax4.title.set_text("expenditure on education")
ax5.plot(xdata1,ydata5, color = 'tab:purple')
ax5.title.set_text("teachers enrollment to secondary")
ax6.plot(xdata1,ydata6, color = 'tab:blue')
ax6.title.set_text("student teacher ratio")

plt.suptitle("Hong Kong SAR, China Graphs",fontsize = 15)
plt.show()

# %% [markdown]
# ### STUDENT ENROLLMENT AND INTERNET USERS ARE MORE , BUT EXPENDITURE ON SECONDARY IS LESS  , BUT ALSO YOU CAN SET UP THE ONLINE COURSE
#
# > Indented block

# %% [markdown]
# ### Based on the above analysis we can conclude
#
# ## Which countries have a high customer potential for our services?
# # India ,Hong Kong SAR China,Indonesia
#
#
# ## In which countries should one set up first?
# #India
